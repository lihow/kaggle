# %%
import os
import glob
import math
import torch
import torchvision
import numpy as np
import pandas as pd
from PIL import Image
import torch.nn as nn
from torchnet import meter
from progressbar import * #进度条
from natsort import natsorted
import torch.nn.functional as F #torch是关于运算的包
import matplotlib.pyplot as plt
from collections import OrderedDict
from torch.autograd import Variable
from torch.utils.data import Dataset
from torchvision import transforms as T
from torchvision import datasets,transforms, models #torchvision则是打包了一些数据集

#如果多gpu运行，屏蔽下一句
os.environ['CUDA_VISIBLE_DEVICES']='2'

# %%
class _DenseLayer(nn.Sequential):
    def __init__(self, num_input_features, growth_rate, bn_size, drop_rate):
        super(_DenseLayer, self).__init__()
        self.add_module('norm1', nn.BatchNorm2d(num_input_features))
        self.add_module('relu1', nn.ReLU(inplace=True))
        self.add_module('conv1', nn.Conv2d(num_input_features, bn_size*growth_rate, kernel_size=1, stride=1, bias=False))
        #引入1*1卷积来降低维度 DenseNet-B
        self.add_module('norm2', nn.BatchNorm2d(bn_size*growth_rate))
        self.add_module('relu2', nn.ReLU(inplace=True))
        self.add_module('conv2', nn.Conv2d(bn_size*growth_rate, growth_rate, kernel_size=3, stride=1, padding=1, bias=False))
        self.drop_rate = drop_rate
    def forward(self, x):
        new_features = super(_DenseLayer, self).forward(x)
        if self.drop_rate > 0:
            new_features = F.dropout(new_features, p=self.drop_rate, training=self.training)
        return torch.cat([x, new_features], 1)
class _DenseBlock(nn.Sequential):
    def __init__(self, num_layers, num_input_features, bn_size, growth_rate, drop_rate):
        super(_DenseBlock, self).__init__()
        for i in range(num_layers):
            layer = _DenseLayer(num_input_features + i*growth_rate, growth_rate, bn_size, drop_rate)
            self.add_module('denselayer%d' % (i+1), layer)
class _Transition(nn.Sequential):
    def __init__(self, num_input_features, num_output_features):
        super(_Transition, self).__init__()
        self.add_module('norm', nn.BatchNorm2d(num_input_features))
        self.add_module('relu', nn.ReLU(inplace=True))
        self.add_module('conv', nn.Conv2d(num_input_features, num_output_features, kernel_size=1, stride=1, bias=False))
        self.add_module('pool', nn.AvgPool2d(kernel_size=2, stride=2))

# %%
class DenseNet(nn.Module):
    def __init__(self, growth_rate=12, block_config=(16, 16, 16),
                 num_init_features=24, bn_size=4, drop_rate=0, num_classes=10):
        super(DenseNet, self).__init__()
        print(num_init_features, block_config, growth_rate)
        #first convolution
        self.features = nn.Sequential(OrderedDict([
            ('conv0', nn.Conv2d(3, num_init_features, kernel_size=3, stride=1, padding=1, bias=False))
        ]))
        #Each denseblock
        num_features = num_init_features
        for i, num_layers in enumerate(block_config):
            block = _DenseBlock(num_layers=num_layers, num_input_features=num_features, bn_size=bn_size, growth_rate=growth_rate, \
                               drop_rate=drop_rate)
            self.features.add_module('denseblock%d' % (i+1), block)
            num_features = num_features + num_layers*growth_rate
            if i != len(block_config)-1:
                trans = _Transition(num_input_features=num_features, num_output_features=num_features//2)
                self.features.add_module('transition%d' % (i+1), trans)
                num_features = num_features//2
                #DenseNet-C 0.5
        #Final bath norm
        self.features.add_module('norm5', nn.BatchNorm2d(num_features))
        #Linear layer
        self.classifer = nn.Linear(num_features, num_classes)
        #initialize conv and bn parameters
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0]*m.kernel_size[1]*m.out_channels
                m.weight.data.normal_(0, math.sqrt(2./n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
    def forward(self, x):
        features = self.features(x)
        out = F.relu(features, inplace=True)
        out = F.avg_pool2d(out, kernel_size=8, stride=1).view(features.size(0), -1)
        out = self.classifer(out)
        return out

# %%
def densenet_BC(depth, k, **kwargs):
    N = (depth-4)//6 #total_num_layer = 2 + 2*3*N + 2 =>[in+out+dense_block+trans] 
    model = DenseNet(growth_rate=k, block_config=[N, N, N], num_init_features=2*k, **kwargs)
    return model

# %%
#net = DenseNet()
#net = densenet_BC(190, 40, num_classes=10)
#input = torch.randn(1, 3, 32, 32)
#y = net(input)
#print(net)
#print(y.size())

# %%
label2int = {'airplane':0, 'automobile':1, 'bird':2, 'cat':3, 'deer':4, 'dog':5, 'frog':6, 'horse':7, 'ship':8, 'truck':9}
int2lable = {0:'airplane', 1:'automobile', 2:'bird', 3:'cat', 4:'deer', 5:'dog', 6:'frog', 7:'horse', 8:'ship', 9:'truck'}

# %%
class TrainAndValData(Dataset):
    def __init__(self, img_path, csv_path, train=True, transforms=None):
        '''
        获得所有图片路径，并划分训练集、验证集
        '''
        self.train = train
        files = natsorted(glob.glob(img_path + '/*'))
        labels = pd.read_csv(csv_path).values[:, 1]
        files_num = len(files)
        break_point = int(0.9*files_num)
        if self.train:
            self.img_name = files[: break_point]
            self.img_label = labels[: break_point]
        else:
            self.img_name = files[break_point: ]
            self.img_label = labels[break_point: ]
         
   

        #数据增强
        if transforms is None:
            normalize = T.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.2023, 0.1994, 0.2010])
            #训练集用数据增强
            if self.train:
                self.transforms = T.Compose([
                    #T.RandomCrop(224, padding=4),  #先四周填充0，在吧图像随机裁剪成32*32`，
                    T.Resize(40),
                    T.RandomResizedCrop(32),
                    T.RandomHorizontalFlip(),  #图像一半的概率翻转，一半的概率不翻转
                    #T.RandomVerticalFlip(),
                    T.ToTensor(),
                    normalize 
                ])
            else:
                self.transforms = T.Compose([
                    T.Resize(32),
                    #T.CenterCrop(224),#中心裁剪
                    T.ToTensor(),
                    normalize 
                ])
    def __len__(self):
        '''
        返回数据集中所有图片的个数
        '''
        return len(self.img_name)
    def __getitem__(self, index):
        '''
        返回一张图片的数据
        '''
        img_path = self.img_name[index]
        img = Image.open(img_path)
        img = self.transforms(img)
        label = label2int[self.img_label[index]]
        return img, label
class TestData(Dataset):
    def __init__(self, img_path, transforms=None):
        files = natsorted(glob.glob(img_path + '/*'))
        self.img_name = files
        if transforms is None:
            normalize = T.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.2023, 0.1994, 0.2010])
            self.transforms =  T.Compose([
                T.Resize(32),
                T.ToTensor(),
                normalize
            ])
    def __len__(self):
        return len(self.img_name)
    def __getitem__(self, index):
        img_path = self.img_name[index]
        img = Image.open(img_path)
        img = self.transforms(img)
        return img

# %%
train_img_path = 'data/train'
csv_path = 'data/trainLabels.csv'
test_img_path = 'data/test'
train_dataset = TrainAndValData(train_img_path, csv_path, train=True)
val_dataset = TrainAndValData(train_img_path, csv_path, train=False)
test_dataset = TestData(test_img_path)

# %%
print('train len is %d' % len(train_dataset))
print(train_dataset[0][0].shape)
print(train_dataset[0][1])#打印标签
print('val len is %d' % len(val_dataset))
print(val_dataset[0][0].shape)
print(val_dataset[0][1])
print('test len is %d' % len(test_dataset))
print(test_dataset[0].shape)
# Out:
# train len is 45000
# torch.Size([3, 32, 32])
# 6
# val len is 5000
# torch.Size([3, 32, 32])
# 7
# test len is 300000
# torch.Size([3, 32, 32])

# %%
# 超参数设置
EPOCH = 135   #遍历数据集次数
BATCH_SIZE = 120      #批处理尺寸(batch_size)
#LR = 0.001        #学习率
lr = 0.001
lr_decay = 0.995
weight_decay = 1e-4
model_path = 'model/densenet/wide_resnet.pkl'

# %%
trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=8)
valloader = torch.utils.data.DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=8) 


net = DenseNet()
#net = densenet_BC(190, 40, num_classes=10)
#net = net.to(device)
##单GPU
#net = net.cuda()
##多GPU
if torch.cuda.device_count() > 1:
    net = nn.DataParallel(net, device_ids=[0,1])
net = net.cuda()
# 定义损失函数和优化方式
criterion = nn.CrossEntropyLoss()  #损失函数为交叉熵，多用于多分类问题
optimizer = torch.optim.SGD(net.parameters(), lr=lr, momentum=0.9, weight_decay=5e-4) #优化方式为mini-batch momentum-SGD，并采用L2正则化（权重衰减）
#optimizer = torch.optim.Adam(net.parameters(), lr=lr, weight_decay=weight_decay)
#保存模型判断条件
max_val_acc = 0
pre_epoch = 0
max_interval_epoch = 20
pre_train_loss = 100000

print("Start Training...")
for epoch in range(400):
    #训练集
    train_loss = 0
    train_count = 0
    net.train()
    for i, data in enumerate(trainloader):
        inputs, labels = data
        #inputs, labels = inputs.to(device), labels.to(device) # 注意需要复制到GPU
        inputs, labels = inputs.cuda(), labels.cuda()
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        #更新指标
        train_count += labels.size(0)
        train_loss += loss.item()
    train_loss /= train_count

    #验证集
    val_acc = 0
    val_loss = 0
    val_count = 0
    net.eval()
    for i, data in enumerate(valloader):
        inputs, labels = data
        #inputs, labels = inputs.to(device), labels.to(device) # 注意需要复制到GPU
        inputs, labels =  inputs.cuda(), labels.cuda()
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        #更新指标
        val_count += 1
        val_loss += loss.item()
        _, predict = outputs.max(1)
        val_count += labels.size(0)
        val_acc += (predict == labels).sum().item()
    val_acc /= val_count
    val_loss /= val_count
    # print the loss and accuracy
    print('the epoch %d, the train loss is %f, the test loss is %f, the test acc is %f' % (epoch, train_loss, val_loss, val_acc))

    #保存模型
    if val_acc > max_val_acc:
        max_val_acc = val_acc
        pre_epoch = epoch
        torch.save(net, model_path)#保存整个神经网络的的结构信息和模型参数信息，save的对象是网络net
    if epoch - pre_epoch > max_interval_epoch:
        print('early stop')
        break

    #如果损失不载下降，则降低学习率
    if train_loss > pre_train_loss:
        lr = lr*lr_decay
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
    pre_train_loss = pre_train_loss
print("Done Training!")
# Out:
# 24 (16, 16, 16) 12
# Start Training...
# the epoch 0, the train loss is 0.017821, the test loss is 0.016679, the test acc is 0.285006
# /home/lhw/anaconda3/lib/python3.6/site-packages/torch/serialization.py:241: UserWarning: Couldn't retrieve source code for container of type DenseNet. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/lhw/anaconda3/lib/python3.6/site-packages/torch/serialization.py:241: UserWarning: Couldn't retrieve source code for container of type _DenseBlock. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/lhw/anaconda3/lib/python3.6/site-packages/torch/serialization.py:241: UserWarning: Couldn't retrieve source code for container of type _DenseLayer. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/lhw/anaconda3/lib/python3.6/site-packages/torch/serialization.py:241: UserWarning: Couldn't retrieve source code for container of type _Transition. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# the epoch 1, the train loss is 0.016316, the test loss is 0.015777, the test acc is 0.310194
# the epoch 2, the train loss is 0.015686, the test loss is 0.015051, the test acc is 0.343514
# the epoch 3, the train loss is 0.015268, the test loss is 0.014709, the test acc is 0.354621
# the epoch 4, the train loss is 0.014977, the test loss is 0.014365, the test acc is 0.368306
# the epoch 5, the train loss is 0.014712, the test loss is 0.014234, the test acc is 0.360571
# the epoch 6, the train loss is 0.014534, the test loss is 0.013981, the test acc is 0.373463
# the epoch 7, the train loss is 0.014338, the test loss is 0.013922, the test acc is 0.363943
# the epoch 8, the train loss is 0.014209, the test loss is 0.013711, the test acc is 0.382586
# the epoch 9, the train loss is 0.014000, the test loss is 0.013418, the test acc is 0.393098
# the epoch 10, the train loss is 0.013837, the test loss is 0.013275, the test acc is 0.406981
# the epoch 11, the train loss is 0.013660, the test loss is 0.013101, the test acc is 0.405990
# the epoch 12, the train loss is 0.013547, the test loss is 0.012961, the test acc is 0.415906
# the epoch 13, the train loss is 0.013425, the test loss is 0.012879, the test acc is 0.420071
# the epoch 14, the train loss is 0.013247, the test loss is 0.012791, the test acc is 0.422848
# the epoch 15, the train loss is 0.013117, the test loss is 0.012713, the test acc is 0.433360
# the epoch 16, the train loss is 0.013060, the test loss is 0.012506, the test acc is 0.434748
# the epoch 17, the train loss is 0.012848, the test loss is 0.012374, the test acc is 0.443276
# the epoch 18, the train loss is 0.012769, the test loss is 0.012391, the test acc is 0.446648
# the epoch 19, the train loss is 0.012635, the test loss is 0.012173, the test acc is 0.454978
# the epoch 20, the train loss is 0.012537, the test loss is 0.012016, the test acc is 0.463507
# the epoch 21, the train loss is 0.012397, the test loss is 0.011803, the test acc is 0.483142
# the epoch 22, the train loss is 0.012322, the test loss is 0.011795, the test acc is 0.487108
# the epoch 23, the train loss is 0.012212, the test loss is 0.011733, the test acc is 0.477390
# the epoch 24, the train loss is 0.012088, the test loss is 0.011387, the test acc is 0.492860
# the epoch 25, the train loss is 0.012007, the test loss is 0.011321, the test acc is 0.503173
# the epoch 26, the train loss is 0.011983, the test loss is 0.011177, the test acc is 0.499802
# the epoch 27, the train loss is 0.011886, the test loss is 0.011211, the test acc is 0.508925
# the epoch 28, the train loss is 0.011832, the test loss is 0.011018, the test acc is 0.515867
# the epoch 29, the train loss is 0.011697, the test loss is 0.010938, the test acc is 0.513288
# the epoch 30, the train loss is 0.011641, the test loss is 0.010794, the test acc is 0.529155
# the epoch 31, the train loss is 0.011584, the test loss is 0.010742, the test acc is 0.529750
# the epoch 32, the train loss is 0.011477, the test loss is 0.010615, the test acc is 0.547600
# the epoch 33, the train loss is 0.011422, the test loss is 0.010781, the test acc is 0.536890
# the epoch 34, the train loss is 0.011326, the test loss is 0.010825, the test acc is 0.534907
# the epoch 35, the train loss is 0.011293, the test loss is 0.010549, the test acc is 0.539667
# the epoch 36, the train loss is 0.011249, the test loss is 0.010398, the test acc is 0.549187
# the epoch 37, the train loss is 0.011202, the test loss is 0.010670, the test acc is 0.543832
# the epoch 38, the train loss is 0.011145, the test loss is 0.010266, the test acc is 0.556922
# the epoch 39, the train loss is 0.011027, the test loss is 0.010281, the test acc is 0.560690
# the epoch 40, the train loss is 0.011006, the test loss is 0.010189, the test acc is 0.561087
# the epoch 41, the train loss is 0.010934, the test loss is 0.010503, the test acc is 0.548988
# the epoch 42, the train loss is 0.010870, the test loss is 0.010279, the test acc is 0.557914
# the epoch 43, the train loss is 0.010813, the test loss is 0.010354, the test acc is 0.554344
# the epoch 44, the train loss is 0.010763, the test loss is 0.010789, the test acc is 0.535502
# the epoch 45, the train loss is 0.010727, the test loss is 0.009786, the test acc is 0.581515
# the epoch 46, the train loss is 0.010696, the test loss is 0.009939, the test acc is 0.571202
# the epoch 47, the train loss is 0.010638, the test loss is 0.009853, the test acc is 0.578540
# the epoch 48, the train loss is 0.010623, the test loss is 0.009884, the test acc is 0.568227
# the epoch 49, the train loss is 0.010560, the test loss is 0.009808, the test acc is 0.578540
# the epoch 50, the train loss is 0.010536, the test loss is 0.009761, the test acc is 0.585284
# the epoch 51, the train loss is 0.010490, the test loss is 0.009826, the test acc is 0.584292
# the epoch 52, the train loss is 0.010357, the test loss is 0.009833, the test acc is 0.580920
# the epoch 53, the train loss is 0.010316, the test loss is 0.009892, the test acc is 0.577747
# the epoch 54, the train loss is 0.010331, the test loss is 0.009619, the test acc is 0.590639
# the epoch 55, the train loss is 0.010224, the test loss is 0.009478, the test acc is 0.596192
# the epoch 56, the train loss is 0.010194, the test loss is 0.009757, the test acc is 0.585482
# the epoch 57, the train loss is 0.010130, the test loss is 0.009771, the test acc is 0.594407
# the epoch 58, the train loss is 0.010108, the test loss is 0.009988, the test acc is 0.578540
# the epoch 59, the train loss is 0.010131, the test loss is 0.009519, the test acc is 0.597580
# the epoch 60, the train loss is 0.010004, the test loss is 0.009518, the test acc is 0.599564
# the epoch 61, the train loss is 0.010052, the test loss is 0.009506, the test acc is 0.602935
# the epoch 62, the train loss is 0.009949, the test loss is 0.009559, the test acc is 0.599167
# the epoch 63, the train loss is 0.009906, the test loss is 0.009380, the test acc is 0.608687
# the epoch 64, the train loss is 0.009879, the test loss is 0.009409, the test acc is 0.605712
# the epoch 65, the train loss is 0.009826, the test loss is 0.009373, the test acc is 0.608885
# the epoch 66, the train loss is 0.009806, the test loss is 0.009225, the test acc is 0.612654
# the epoch 67, the train loss is 0.009721, the test loss is 0.009611, the test acc is 0.598770
# the epoch 68, the train loss is 0.009748, the test loss is 0.009498, the test acc is 0.595200
# the epoch 69, the train loss is 0.009787, the test loss is 0.009003, the test acc is 0.620190
# the epoch 70, the train loss is 0.009688, the test loss is 0.009297, the test acc is 0.612455
# the epoch 71, the train loss is 0.009643, the test loss is 0.009753, the test acc is 0.598969
# the epoch 72, the train loss is 0.009554, the test loss is 0.009925, the test acc is 0.590044
# the epoch 73, the train loss is 0.009551, the test loss is 0.008934, the test acc is 0.625347
# the epoch 74, the train loss is 0.009506, the test loss is 0.009007, the test acc is 0.622967
# the epoch 75, the train loss is 0.009517, the test loss is 0.009077, the test acc is 0.626735
# the epoch 76, the train loss is 0.009460, the test loss is 0.008654, the test acc is 0.633677
# the epoch 77, the train loss is 0.009388, the test loss is 0.008914, the test acc is 0.624950
# the epoch 78, the train loss is 0.009380, the test loss is 0.008871, the test acc is 0.626537
# the epoch 79, the train loss is 0.009351, the test loss is 0.008955, the test acc is 0.627132
# the epoch 80, the train loss is 0.009307, the test loss is 0.009138, the test acc is 0.627132
# the epoch 81, the train loss is 0.009301, the test loss is 0.008524, the test acc is 0.644585
# the epoch 82, the train loss is 0.009254, the test loss is 0.009312, the test acc is 0.619397
# the epoch 83, the train loss is 0.009204, the test loss is 0.008301, the test acc is 0.649345
# the epoch 84, the train loss is 0.009175, the test loss is 0.008692, the test acc is 0.637247
# the epoch 85, the train loss is 0.009120, the test loss is 0.009067, the test acc is 0.622967
# the epoch 86, the train loss is 0.009062, the test loss is 0.009071, the test acc is 0.628322
# the epoch 87, the train loss is 0.009084, the test loss is 0.008971, the test acc is 0.625942
# the epoch 88, the train loss is 0.009090, the test loss is 0.008973, the test acc is 0.636255
# the epoch 89, the train loss is 0.009022, the test loss is 0.009013, the test acc is 0.633479
# the epoch 90, the train loss is 0.009023, the test loss is 0.008993, the test acc is 0.633875
# the epoch 91, the train loss is 0.008991, the test loss is 0.008970, the test acc is 0.637842
# the epoch 92, the train loss is 0.008918, the test loss is 0.008417, the test acc is 0.647560
# the epoch 93, the train loss is 0.008931, the test loss is 0.008427, the test acc is 0.649147
# the epoch 94, the train loss is 0.008926, the test loss is 0.008133, the test acc is 0.657676
# the epoch 95, the train loss is 0.008880, the test loss is 0.008749, the test acc is 0.638239
# the epoch 96, the train loss is 0.008808, the test loss is 0.008785, the test acc is 0.643594
# the epoch 97, the train loss is 0.008811, the test loss is 0.009240, the test acc is 0.624752
# the epoch 98, the train loss is 0.008762, the test loss is 0.008314, the test acc is 0.655097
# the epoch 99, the train loss is 0.008738, the test loss is 0.008157, the test acc is 0.664816
# the epoch 100, the train loss is 0.008724, the test loss is 0.008402, the test acc is 0.654701
# the epoch 101, the train loss is 0.008721, the test loss is 0.008041, the test acc is 0.668981
# the epoch 102, the train loss is 0.008700, the test loss is 0.008860, the test acc is 0.648354
# the epoch 103, the train loss is 0.008644, the test loss is 0.007867, the test acc is 0.670369
# the epoch 104, the train loss is 0.008585, the test loss is 0.008577, the test acc is 0.652321
# the epoch 105, the train loss is 0.008647, the test loss is 0.008387, the test acc is 0.657874
# the epoch 106, the train loss is 0.008510, the test loss is 0.008614, the test acc is 0.653114
# the epoch 107, the train loss is 0.008547, the test loss is 0.008107, the test acc is 0.666402
# the epoch 108, the train loss is 0.008499, the test loss is 0.009199, the test acc is 0.639429
# the epoch 109, the train loss is 0.008524, the test loss is 0.008109, the test acc is 0.664419
# the epoch 110, the train loss is 0.008455, the test loss is 0.008365, the test acc is 0.656882
# the epoch 111, the train loss is 0.008454, the test loss is 0.008185, the test acc is 0.662039
# the epoch 112, the train loss is 0.008403, the test loss is 0.008528, the test acc is 0.659262
# the epoch 113, the train loss is 0.008394, the test loss is 0.007921, the test acc is 0.669179
# the epoch 114, the train loss is 0.008350, the test loss is 0.009399, the test acc is 0.634669
# the epoch 115, the train loss is 0.008367, the test loss is 0.007767, the test acc is 0.677112
# the epoch 116, the train loss is 0.008322, the test loss is 0.008507, the test acc is 0.658667
# the epoch 117, the train loss is 0.008257, the test loss is 0.009402, the test acc is 0.642007
# the epoch 118, the train loss is 0.008296, the test loss is 0.008163, the test acc is 0.664221
# the epoch 119, the train loss is 0.008264, the test loss is 0.008342, the test acc is 0.657874
# the epoch 120, the train loss is 0.008271, the test loss is 0.008590, the test acc is 0.657081
# the epoch 121, the train loss is 0.008243, the test loss is 0.008691, the test acc is 0.656089
# the epoch 122, the train loss is 0.008187, the test loss is 0.007609, the test acc is 0.681476
# the epoch 123, the train loss is 0.008151, the test loss is 0.008333, the test acc is 0.669774
# the epoch 124, the train loss is 0.008153, the test loss is 0.008065, the test acc is 0.676121
# the epoch 125, the train loss is 0.008196, the test loss is 0.007388, the test acc is 0.695161
# the epoch 126, the train loss is 0.008117, the test loss is 0.009001, the test acc is 0.650734
# the epoch 127, the train loss is 0.008056, the test loss is 0.007977, the test acc is 0.680286
# the epoch 128, the train loss is 0.008108, the test loss is 0.009223, the test acc is 0.646370
# the epoch 129, the train loss is 0.008046, the test loss is 0.008863, the test acc is 0.651131
# the epoch 130, the train loss is 0.008034, the test loss is 0.007549, the test acc is 0.684847
# the epoch 131, the train loss is 0.007991, the test loss is 0.008205, the test acc is 0.665609
# the epoch 132, the train loss is 0.007982, the test loss is 0.008862, the test acc is 0.647957
# the epoch 133, the train loss is 0.007950, the test loss is 0.008271, the test acc is 0.666006
# the epoch 134, the train loss is 0.007933, the test loss is 0.007660, the test acc is 0.687227
# the epoch 135, the train loss is 0.007884, the test loss is 0.008361, the test acc is 0.667196
# the epoch 136, the train loss is 0.007912, the test loss is 0.007547, the test acc is 0.691194
# the epoch 137, the train loss is 0.007884, the test loss is 0.007626, the test acc is 0.684252
# the epoch 138, the train loss is 0.007831, the test loss is 0.007772, the test acc is 0.686236
# the epoch 139, the train loss is 0.007863, the test loss is 0.008336, the test acc is 0.676716
# the epoch 140, the train loss is 0.007829, the test loss is 0.008087, the test acc is 0.679889
# the epoch 141, the train loss is 0.007815, the test loss is 0.008869, the test acc is 0.655296
# the epoch 142, the train loss is 0.007818, the test loss is 0.007738, the test acc is 0.690401
# the epoch 143, the train loss is 0.007810, the test loss is 0.008984, the test acc is 0.657279
# the epoch 144, the train loss is 0.007691, the test loss is 0.007452, the test acc is 0.697937
# the epoch 145, the train loss is 0.007745, the test loss is 0.007916, the test acc is 0.686037
# the epoch 146, the train loss is 0.007741, the test loss is 0.007518, the test acc is 0.694962
# the epoch 147, the train loss is 0.007679, the test loss is 0.007701, the test acc is 0.690599
# the epoch 148, the train loss is 0.007680, the test loss is 0.007901, the test acc is 0.685839
# the epoch 149, the train loss is 0.007646, the test loss is 0.007177, the test acc is 0.705672
# the epoch 150, the train loss is 0.007606, the test loss is 0.008406, the test acc is 0.667791
# the epoch 151, the train loss is 0.007566, the test loss is 0.007508, the test acc is 0.699722
# the epoch 152, the train loss is 0.007577, the test loss is 0.009888, the test acc is 0.644387
# the epoch 153, the train loss is 0.007523, the test loss is 0.007289, the test acc is 0.697541
# the epoch 154, the train loss is 0.007542, the test loss is 0.008888, the test acc is 0.659659
# the epoch 155, the train loss is 0.007512, the test loss is 0.007921, the test acc is 0.684252
# the epoch 156, the train loss is 0.007504, the test loss is 0.008703, the test acc is 0.665609
# the epoch 157, the train loss is 0.007451, the test loss is 0.007407, the test acc is 0.708251
# the epoch 158, the train loss is 0.007461, the test loss is 0.007038, the test acc is 0.712217
# the epoch 159, the train loss is 0.007439, the test loss is 0.008410, the test acc is 0.679492
# the epoch 160, the train loss is 0.007398, the test loss is 0.009741, the test acc is 0.636057
# the epoch 161, the train loss is 0.007453, the test loss is 0.007060, the test acc is 0.712416
# the epoch 162, the train loss is 0.007419, the test loss is 0.007798, the test acc is 0.698929
# the epoch 163, the train loss is 0.007397, the test loss is 0.007373, the test acc is 0.701507
# the epoch 164, the train loss is 0.007296, the test loss is 0.007279, the test acc is 0.709441
# the epoch 165, the train loss is 0.007347, the test loss is 0.009439, the test acc is 0.655097
# the epoch 166, the train loss is 0.007374, the test loss is 0.007769, the test acc is 0.696351
# the epoch 167, the train loss is 0.007324, the test loss is 0.007320, the test acc is 0.710432
# the epoch 168, the train loss is 0.007272, the test loss is 0.006496, the test acc is 0.734034
# the epoch 169, the train loss is 0.007287, the test loss is 0.006709, the test acc is 0.728481
# the epoch 170, the train loss is 0.007245, the test loss is 0.007331, the test acc is 0.711226
# the epoch 171, the train loss is 0.007243, the test loss is 0.007739, the test acc is 0.697937
# the epoch 172, the train loss is 0.007228, the test loss is 0.008033, the test acc is 0.693971
# the epoch 173, the train loss is 0.007229, the test loss is 0.006475, the test acc is 0.738001
# the epoch 174, the train loss is 0.007179, the test loss is 0.006084, the test acc is 0.750298
# the epoch 175, the train loss is 0.007174, the test loss is 0.007223, the test acc is 0.713011
# the epoch 176, the train loss is 0.007138, the test loss is 0.006533, the test acc is 0.734232
# the epoch 177, the train loss is 0.007115, the test loss is 0.007039, the test acc is 0.724712
# the epoch 178, the train loss is 0.007139, the test loss is 0.007101, the test acc is 0.723721
# the epoch 179, the train loss is 0.007116, the test loss is 0.008021, the test acc is 0.695359
# the epoch 180, the train loss is 0.007121, the test loss is 0.007559, the test acc is 0.708052
# the epoch 181, the train loss is 0.007035, the test loss is 0.007274, the test acc is 0.713209
# the epoch 182, the train loss is 0.007114, the test loss is 0.006397, the test acc is 0.735819
# the epoch 183, the train loss is 0.007052, the test loss is 0.006618, the test acc is 0.727092
# the epoch 184, the train loss is 0.006986, the test loss is 0.006402, the test acc is 0.735819
# the epoch 185, the train loss is 0.006989, the test loss is 0.009140, the test acc is 0.665014
# the epoch 186, the train loss is 0.006961, the test loss is 0.007475, the test acc is 0.717771
# the epoch 187, the train loss is 0.006982, the test loss is 0.007133, the test acc is 0.720547
# the epoch 188, the train loss is 0.006992, the test loss is 0.006407, the test acc is 0.739389
# the epoch 189, the train loss is 0.006943, the test loss is 0.007172, the test acc is 0.722332
# the epoch 190, the train loss is 0.006959, the test loss is 0.007000, the test acc is 0.722332
# the epoch 191, the train loss is 0.006917, the test loss is 0.006543, the test acc is 0.735224
# the epoch 192, the train loss is 0.006860, the test loss is 0.006409, the test acc is 0.747917
# the epoch 193, the train loss is 0.006938, the test loss is 0.007736, the test acc is 0.702102
# the epoch 194, the train loss is 0.006842, the test loss is 0.007455, the test acc is 0.713606
# the epoch 195, the train loss is 0.006869, the test loss is 0.006806, the test acc is 0.732447
# early stop
# Done Training!
