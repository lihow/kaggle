# %%
import os
import glob
import torch
import torchvision
import numpy as np
import pandas as pd
from PIL import Image
import torch.nn as nn
from torchnet import meter
from progressbar import * #进度条
from natsort import natsorted
import torch.nn.functional as F #torch是关于运算的包
import matplotlib.pyplot as plt
from torch.autograd import Variable
from torch.utils.data import Dataset
from torchvision import transforms as T
from torchvision import datasets,transforms, models #torchvision则是打包了一些数据集

#如果多gpu运行，屏蔽下一句
#os.environ['CUDA_VISIBLE_DEVICES']='2'

# %%
class wide_basic(nn.Module):
    def __init__(self, in_planes, out_planes, dropout_rate, stride=1):
        super(wide_basic, self).__init__()
        self.left = nn.Sequential(
            nn.BatchNorm2d(in_planes),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride, padding=2, bias=True),
            nn.Dropout(p=dropout_rate),
            nn.BatchNorm2d(out_planes),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_planes, out_planes, kernel_size=3, stride=1, padding=1, bias=True)
        )
        
        self.bn1 = nn.BatchNorm2d(in_planes)
        self.conv1 = nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride, padding=1, bias=True)
        self.dropout = nn.Dropout(p=dropout_rate)
        self.bn2 = nn.BatchNorm2d(out_planes)
        self.relu2 = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(out_planes, out_planes, kernel_size=3, stride=1, padding=1, bias=True)
        
        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != out_planes:
            self.shortcut = nn.Sequential(nn.Conv2d(in_planes, out_planes, kernel_size=1, stride=stride, bias=True))
    def forward(self, x):
        out = self.dropout(self.conv1(F.relu(self.bn1(x))))
        out = self.conv2(F.relu(self.bn2(out)))
        #out = self.left(x)
        out += self.shortcut(x)
        
        return out

# %%
class Wide_ResNet(nn.Module):
    def __init__(self, depth, widen_factor, dropout_rate, num_classes=10):
        super(Wide_ResNet, self).__init__()
        self.in_planes = 16
        assert ((depth-2)%6 == 0), 'Wide-resnet depth should be 6n+2'
        n = int((depth-2)/6)
        k = widen_factor
        print('| Wide-Resnet %dx%d' % (n, k))
        n_stages = [16, 16*k, 32*k, 64*k]
        self.conv1 = nn.Conv2d(3, n_stages[0], kernel_size=3, stride=1, padding=1, bias=True)
        self.layer1 = self._wide_layer(wide_basic, n_stages[1], n, dropout_rate, stride=1)
        self.layer2 = self._wide_layer(wide_basic, n_stages[2], n, dropout_rate, stride=2)
        self.layer3 = self._wide_layer(wide_basic, n_stages[3], n, dropout_rate, stride=2)
        self.bn1 = nn.BatchNorm2d(n_stages[3], momentum=0.9)
        self.linear = nn.Linear(n_stages[3], num_classes)
    def _wide_layer(self, block, planes, num_blocks, dropout_rate, stride):
        #print(num_blocks)
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        
        for stride in strides:
            layers.append(block(self.in_planes, planes, dropout_rate, stride))
            self.in_planes = planes
        return nn.Sequential(*layers)
    def forward(self, x):
        out = self.conv1(x)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = F.relu(self.bn1(out))
        out = F.avg_pool2d(out, 8)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        
        return out

# %%
#相比于ResNet只是在 原有基础上加深了卷积层数
#print(Wide_ResNet(26, 10, 0.3, 10))

# %%
label2int = {'airplane':0, 'automobile':1, 'bird':2, 'cat':3, 'deer':4, 'dog':5, 'frog':6, 'horse':7, 'ship':8, 'truck':9}
int2lable = {0:'airplane', 1:'automobile', 2:'bird', 3:'cat', 4:'deer', 5:'dog', 6:'frog', 7:'horse', 8:'ship', 9:'truck'}

# %%
class TrainAndValData(Dataset):
    def __init__(self, img_path, csv_path, train=True, transforms=None):
        '''
        获得所有图片路径，并划分训练集、验证集
        '''
        self.train = train
        files = natsorted(glob.glob(img_path + '/*'))
        labels = pd.read_csv(csv_path).values[:, 1]
        files_num = len(files)
        break_point = int(0.9*files_num)
        if self.train:
            self.img_name = files[: break_point]
            self.img_label = labels[: break_point]
        else:
            self.img_name = files[break_point: ]
            self.img_label = labels[break_point: ]
         
   

        #数据增强
        if transforms is None:
            normalize = T.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.2023, 0.1994, 0.2010])
            #训练集用数据增强
            if self.train:
                self.transforms = T.Compose([
                    #T.RandomCrop(224, padding=4),  #先四周填充0，在吧图像随机裁剪成32*32`，
                    T.Resize(40),
                    T.RandomResizedCrop(32),
                    T.RandomHorizontalFlip(),  #图像一半的概率翻转，一半的概率不翻转
                    #T.RandomVerticalFlip(),
                    T.ToTensor(),
                    normalize 
                ])
            else:
                self.transforms = T.Compose([
                    T.Resize(32),
                    #T.CenterCrop(224),#中心裁剪
                    T.ToTensor(),
                    normalize 
                ])
    def __len__(self):
        '''
        返回数据集中所有图片的个数
        '''
        return len(self.img_name)
    def __getitem__(self, index):
        '''
        返回一张图片的数据
        '''
        img_path = self.img_name[index]
        img = Image.open(img_path)
        img = self.transforms(img)
        label = label2int[self.img_label[index]]
        return img, label
class TestData(Dataset):
    def __init__(self, img_path, transforms=None):
        files = natsorted(glob.glob(img_path + '/*'))
        self.img_name = files
        if transforms is None:
            normalize = T.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.2023, 0.1994, 0.2010])
            self.transforms =  T.Compose([
                T.Resize(32),
                T.ToTensor(),
                normalize
            ])
    def __len__(self):
        return len(self.img_name)
    def __getitem__(self, index):
        img_path = self.img_name[index]
        img = Image.open(img_path)
        img = self.transforms(img)
        return img

# %%
train_img_path = 'data/train'
csv_path = 'data/trainLabels.csv'
test_img_path = 'data/test'
train_dataset = TrainAndValData(train_img_path, csv_path, train=True)
val_dataset = TrainAndValData(train_img_path, csv_path, train=False)
test_dataset = TestData(test_img_path)

# %%
print('train len is %d' % len(train_dataset))
print(train_dataset[0][0].shape)
print(train_dataset[0][1])#打印标签
print('val len is %d' % len(val_dataset))
print(val_dataset[0][0].shape)
print(val_dataset[0][1])
print('test len is %d' % len(test_dataset))
print(test_dataset[0].shape)
# Out:
# train len is 45000
# torch.Size([3, 32, 32])
# 6
# val len is 5000
# torch.Size([3, 32, 32])
# 7
# test len is 300000
# torch.Size([3, 32, 32])

# %%
# 超参数设置
EPOCH = 135   #遍历数据集次数
BATCH_SIZE = 120      #批处理尺寸(batch_size)
#LR = 0.001        #学习率
lr = 0.001
lr_decay = 0.995
weight_decay = 1e-4
model_path = 'model/wide_resnet/wide_resnet.pkl'

# %%
trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=8)
valloader = torch.utils.data.DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=8) 

device = torch.device("cuda:2")
#net = ResNet_18_34(34)

net = Wide_ResNet(26, 10, 0.3, 10)
#net = net.to(device)
##单GPU
#net = net.cuda()
##多GPU
if torch.cuda.device_count() > 1:
    net = nn.DataParallel(net, device_ids=[0,1])
net = net.cuda()
# 定义损失函数和优化方式
criterion = nn.CrossEntropyLoss()  #损失函数为交叉熵，多用于多分类问题
optimizer = torch.optim.SGD(net.parameters(), lr=lr, momentum=0.9, weight_decay=5e-4) #优化方式为mini-batch momentum-SGD，并采用L2正则化（权重衰减）
#optimizer = torch.optim.Adam(net.parameters(), lr=lr, weight_decay=weight_decay)
#保存模型判断条件
max_val_acc = 0
pre_epoch = 0
max_interval_epoch = 20
pre_train_loss = 100000

print("Start Training...")
for epoch in range(200):
    #训练集
    train_loss = 0
    train_count = 0
    net.train()
    for i, data in enumerate(trainloader):
        inputs, labels = data
        #inputs, labels = inputs.to(device), labels.to(device) # 注意需要复制到GPU
        inputs, labels = inputs.cuda(), labels.cuda()
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        #更新指标
        train_count += labels.size(0)
        train_loss += loss.item()
    train_loss /= train_count

    #验证集
    val_acc = 0
    val_loss = 0
    val_count = 0
    net.eval()
    for i, data in enumerate(valloader):
        inputs, labels = data
        #inputs, labels = inputs.to(device), labels.to(device) # 注意需要复制到GPU
        inputs, labels =  inputs.cuda(), labels.cuda()
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        #更新指标
        val_count += 1
        val_loss += loss.item()
        _, predict = outputs.max(1)
        val_count += labels.size(0)
        val_acc += (predict == labels).sum().item()
    val_acc /= val_count
    val_loss /= val_count
    # print the loss and accuracy
    print('the epoch %d, the train loss is %f, the test loss is %f, the test acc is %f' % (epoch, train_loss, val_loss, val_acc))

    #保存模型
    if val_acc > max_val_acc:
        max_val_acc = val_acc
        pre_epoch = epoch
        torch.save(net, model_path)#保存整个神经网络的的结构信息和模型参数信息，save的对象是网络net
    if epoch - pre_epoch > max_interval_epoch:
        print('early stop')
        break

    #如果损失不载下降，则降低学习率
    if train_loss > pre_train_loss:
        lr = lr*lr_decay
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
    pre_train_loss = pre_train_loss
print("Done Training!")
# Out:
# | Wide-Resnet 4x10
# Start Training...
# the epoch 0, the train loss is 0.016856, the test loss is 0.014714, the test acc is 0.336573
# /home/lhw/anaconda3/lib/python3.6/site-packages/torch/serialization.py:241: UserWarning: Couldn't retrieve source code for container of type Wide_ResNet. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/lhw/anaconda3/lib/python3.6/site-packages/torch/serialization.py:241: UserWarning: Couldn't retrieve source code for container of type wide_basic. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# the epoch 1, the train loss is 0.015043, the test loss is 0.013887, the test acc is 0.361761
# the epoch 2, the train loss is 0.014199, the test loss is 0.014546, the test acc is 0.370290
# the epoch 3, the train loss is 0.013454, the test loss is 0.012009, the test acc is 0.474217
# the epoch 4, the train loss is 0.012683, the test loss is 0.012831, the test acc is 0.481158
# the epoch 5, the train loss is 0.012103, the test loss is 0.022918, the test acc is 0.432170
# the epoch 6, the train loss is 0.011569, the test loss is 0.011221, the test acc is 0.564260
# the epoch 7, the train loss is 0.011122, the test loss is 0.012112, the test acc is 0.546807
# the epoch 8, the train loss is 0.010758, the test loss is 0.011963, the test acc is 0.560889
# the epoch 9, the train loss is 0.010237, the test loss is 0.011549, the test acc is 0.576755
# the epoch 10, the train loss is 0.010035, the test loss is 0.009231, the test acc is 0.639230
# the epoch 11, the train loss is 0.009745, the test loss is 0.008701, the test acc is 0.650337
# the epoch 12, the train loss is 0.009387, the test loss is 0.009124, the test acc is 0.635859
# the epoch 13, the train loss is 0.009109, the test loss is 0.009410, the test acc is 0.642602
# the epoch 14, the train loss is 0.008939, the test loss is 0.008654, the test acc is 0.665212
# the epoch 15, the train loss is 0.008586, the test loss is 0.007727, the test acc is 0.701309
# the epoch 16, the train loss is 0.008373, the test loss is 0.007428, the test acc is 0.708647
# the epoch 17, the train loss is 0.008167, the test loss is 0.008047, the test acc is 0.707457
# the epoch 18, the train loss is 0.007946, the test loss is 0.006934, the test acc is 0.734232
# the epoch 19, the train loss is 0.007794, the test loss is 0.009610, the test acc is 0.670766
# the epoch 20, the train loss is 0.007566, the test loss is 0.007380, the test acc is 0.715986
# the epoch 21, the train loss is 0.007447, the test loss is 0.008403, the test acc is 0.692781
# the epoch 22, the train loss is 0.007303, the test loss is 0.008841, the test acc is 0.693971
# the epoch 23, the train loss is 0.007195, the test loss is 0.007127, the test acc is 0.739587
# the epoch 24, the train loss is 0.007029, the test loss is 0.006265, the test acc is 0.756049
# the epoch 25, the train loss is 0.006892, the test loss is 0.007528, the test acc is 0.735819
# the epoch 26, the train loss is 0.006753, the test loss is 0.006457, the test acc is 0.765569
# the epoch 27, the train loss is 0.006709, the test loss is 0.007138, the test acc is 0.749702
# the epoch 28, the train loss is 0.006568, the test loss is 0.006790, the test acc is 0.755256
# the epoch 29, the train loss is 0.006504, the test loss is 0.006278, the test acc is 0.767354
# the epoch 30, the train loss is 0.006357, the test loss is 0.006903, the test acc is 0.746529
# the epoch 31, the train loss is 0.006315, the test loss is 0.007482, the test acc is 0.753074
# the epoch 32, the train loss is 0.006181, the test loss is 0.004700, the test acc is 0.821499
# the epoch 33, the train loss is 0.006139, the test loss is 0.005293, the test acc is 0.793534
# the epoch 34, the train loss is 0.005994, the test loss is 0.005856, the test acc is 0.780643
# the epoch 35, the train loss is 0.005958, the test loss is 0.006017, the test acc is 0.777668
# the epoch 36, the train loss is 0.005823, the test loss is 0.005022, the test acc is 0.810194
# the epoch 37, the train loss is 0.005817, the test loss is 0.006047, the test acc is 0.783816
# the epoch 38, the train loss is 0.005793, the test loss is 0.005902, the test acc is 0.788179
# the epoch 39, the train loss is 0.005721, the test loss is 0.004850, the test acc is 0.817929
# the epoch 40, the train loss is 0.005609, the test loss is 0.006021, the test acc is 0.795716
# the epoch 41, the train loss is 0.005550, the test loss is 0.005016, the test acc is 0.819119
# the epoch 42, the train loss is 0.005462, the test loss is 0.005938, the test acc is 0.796708
# the epoch 43, the train loss is 0.005446, the test loss is 0.005144, the test acc is 0.813169
# the epoch 44, the train loss is 0.005391, the test loss is 0.005292, the test acc is 0.820706
# the epoch 45, the train loss is 0.005332, the test loss is 0.004837, the test acc is 0.827449
# the epoch 46, the train loss is 0.005237, the test loss is 0.004174, the test acc is 0.842324
# the epoch 47, the train loss is 0.005188, the test loss is 0.003964, the test acc is 0.848274
# the epoch 48, the train loss is 0.005196, the test loss is 0.004462, the test acc is 0.836771
# the epoch 49, the train loss is 0.005110, the test loss is 0.004716, the test acc is 0.832408
# the epoch 50, the train loss is 0.004999, the test loss is 0.004001, the test acc is 0.850853
# the epoch 51, the train loss is 0.005004, the test loss is 0.005493, the test acc is 0.810393
# the epoch 52, the train loss is 0.005000, the test loss is 0.004099, the test acc is 0.848473
# the epoch 53, the train loss is 0.004928, the test loss is 0.004181, the test acc is 0.853035
# the epoch 54, the train loss is 0.004907, the test loss is 0.005370, the test acc is 0.819318
# the epoch 55, the train loss is 0.004841, the test loss is 0.004946, the test acc is 0.845299
# the epoch 56, the train loss is 0.004827, the test loss is 0.005677, the test acc is 0.822293
# the epoch 57, the train loss is 0.004735, the test loss is 0.005057, the test acc is 0.831218
# the epoch 58, the train loss is 0.004709, the test loss is 0.005177, the test acc is 0.840738
# the epoch 59, the train loss is 0.004660, the test loss is 0.004635, the test acc is 0.833598
# the epoch 60, the train loss is 0.004648, the test loss is 0.004322, the test acc is 0.849464
# the epoch 61, the train loss is 0.004596, the test loss is 0.005439, the test acc is 0.829433
# the epoch 62, the train loss is 0.004545, the test loss is 0.004746, the test acc is 0.839548
# the epoch 63, the train loss is 0.004522, the test loss is 0.004996, the test acc is 0.834391
# the epoch 64, the train loss is 0.004539, the test loss is 0.005080, the test acc is 0.844109
# the epoch 65, the train loss is 0.004470, the test loss is 0.004259, the test acc is 0.854621
# the epoch 66, the train loss is 0.004410, the test loss is 0.004030, the test acc is 0.849068
# the epoch 67, the train loss is 0.004399, the test loss is 0.004479, the test acc is 0.845299
# the epoch 68, the train loss is 0.004304, the test loss is 0.006447, the test acc is 0.798096
# the epoch 69, the train loss is 0.004340, the test loss is 0.004469, the test acc is 0.842919
# the epoch 70, the train loss is 0.004291, the test loss is 0.006018, the test acc is 0.821301
# the epoch 71, the train loss is 0.004309, the test loss is 0.005481, the test acc is 0.839944
# the epoch 72, the train loss is 0.004196, the test loss is 0.004387, the test acc is 0.848076
# the epoch 73, the train loss is 0.004188, the test loss is 0.004822, the test acc is 0.853828
# the epoch 74, the train loss is 0.004202, the test loss is 0.005145, the test acc is 0.835581
# the epoch 75, the train loss is 0.004224, the test loss is 0.004304, the test acc is 0.856803
# the epoch 76, the train loss is 0.004111, the test loss is 0.003649, the test acc is 0.875446
# the epoch 77, the train loss is 0.004142, the test loss is 0.004816, the test acc is 0.850060
# the epoch 78, the train loss is 0.004024, the test loss is 0.004361, the test acc is 0.850655
# the epoch 79, the train loss is 0.003992, the test loss is 0.004313, the test acc is 0.866720
# the epoch 80, the train loss is 0.004066, the test loss is 0.004123, the test acc is 0.863745
# the epoch 81, the train loss is 0.003993, the test loss is 0.004943, the test acc is 0.840143
# the epoch 82, the train loss is 0.003925, the test loss is 0.004457, the test acc is 0.854423
# the epoch 83, the train loss is 0.004002, the test loss is 0.004263, the test acc is 0.860770
# the epoch 84, the train loss is 0.003894, the test loss is 0.004464, the test acc is 0.855811
# the epoch 85, the train loss is 0.003887, the test loss is 0.004933, the test acc is 0.853630
# the epoch 86, the train loss is 0.003912, the test loss is 0.005190, the test acc is 0.836573
# the epoch 87, the train loss is 0.003828, the test loss is 0.003756, the test acc is 0.876835
# the epoch 88, the train loss is 0.003843, the test loss is 0.005426, the test acc is 0.843316
# the epoch 89, the train loss is 0.003853, the test loss is 0.004568, the test acc is 0.856010
# the epoch 90, the train loss is 0.003764, the test loss is 0.003847, the test acc is 0.875843
# the epoch 91, the train loss is 0.003739, the test loss is 0.004239, the test acc is 0.868306
# the epoch 92, the train loss is 0.003720, the test loss is 0.005125, the test acc is 0.842523
# the epoch 93, the train loss is 0.003731, the test loss is 0.004834, the test acc is 0.858191
# the epoch 94, the train loss is 0.003734, the test loss is 0.004927, the test acc is 0.847679
# the epoch 95, the train loss is 0.003665, the test loss is 0.005599, the test acc is 0.835383
# the epoch 96, the train loss is 0.003617, the test loss is 0.004239, the test acc is 0.864935
# the epoch 97, the train loss is 0.003624, the test loss is 0.005440, the test acc is 0.840341
# the epoch 98, the train loss is 0.003665, the test loss is 0.003937, the test acc is 0.878620
# the epoch 99, the train loss is 0.003532, the test loss is 0.003597, the test acc is 0.866720
# the epoch 100, the train loss is 0.003567, the test loss is 0.005420, the test acc is 0.846093
# the epoch 101, the train loss is 0.003608, the test loss is 0.003367, the test acc is 0.887545
# the epoch 102, the train loss is 0.003551, the test loss is 0.005197, the test acc is 0.849266
# the epoch 103, the train loss is 0.003497, the test loss is 0.004453, the test acc is 0.873463
# the epoch 104, the train loss is 0.003536, the test loss is 0.004109, the test acc is 0.862951
# the epoch 105, the train loss is 0.003453, the test loss is 0.004100, the test acc is 0.871281
# the epoch 106, the train loss is 0.003485, the test loss is 0.003357, the test acc is 0.882586
# the epoch 107, the train loss is 0.003520, the test loss is 0.003714, the test acc is 0.871678
# the epoch 108, the train loss is 0.003479, the test loss is 0.003859, the test acc is 0.874256
# the epoch 109, the train loss is 0.003454, the test loss is 0.003571, the test acc is 0.885363
# the epoch 110, the train loss is 0.003420, the test loss is 0.004547, the test acc is 0.867513
# the epoch 111, the train loss is 0.003397, the test loss is 0.004106, the test acc is 0.870488
# the epoch 112, the train loss is 0.003408, the test loss is 0.004043, the test acc is 0.873463
# the epoch 113, the train loss is 0.003365, the test loss is 0.004876, the test acc is 0.858588
# the epoch 114, the train loss is 0.003372, the test loss is 0.003596, the test acc is 0.881198
# the epoch 115, the train loss is 0.003314, the test loss is 0.003677, the test acc is 0.881595
# the epoch 116, the train loss is 0.003349, the test loss is 0.004978, the test acc is 0.854621
# the epoch 117, the train loss is 0.003310, the test loss is 0.004100, the test acc is 0.879413
# the epoch 118, the train loss is 0.003306, the test loss is 0.004217, the test acc is 0.865331
# the epoch 119, the train loss is 0.003261, the test loss is 0.004386, the test acc is 0.873066
# the epoch 120, the train loss is 0.003290, the test loss is 0.003073, the test acc is 0.896073
# the epoch 121, the train loss is 0.003243, the test loss is 0.004752, the test acc is 0.867315
# the epoch 122, the train loss is 0.003246, the test loss is 0.003850, the test acc is 0.877231
# the epoch 123, the train loss is 0.003188, the test loss is 0.004203, the test acc is 0.884570
# the epoch 124, the train loss is 0.003219, the test loss is 0.004027, the test acc is 0.878620
# the epoch 125, the train loss is 0.003207, the test loss is 0.005585, the test acc is 0.851250
# the epoch 126, the train loss is 0.003179, the test loss is 0.005665, the test acc is 0.849464
# the epoch 127, the train loss is 0.003148, the test loss is 0.003404, the test acc is 0.895676
# the epoch 128, the train loss is 0.003181, the test loss is 0.004121, the test acc is 0.880206
# the epoch 129, the train loss is 0.003136, the test loss is 0.003559, the test acc is 0.889528
# the epoch 130, the train loss is 0.003163, the test loss is 0.003866, the test acc is 0.882785
# the epoch 131, the train loss is 0.003077, the test loss is 0.003447, the test acc is 0.887743
# the epoch 132, the train loss is 0.003087, the test loss is 0.003393, the test acc is 0.896470
# the epoch 133, the train loss is 0.003135, the test loss is 0.004421, the test acc is 0.874455
# the epoch 134, the train loss is 0.003090, the test loss is 0.004302, the test acc is 0.870686
# the epoch 135, the train loss is 0.003036, the test loss is 0.003937, the test acc is 0.885363
# the epoch 136, the train loss is 0.003104, the test loss is 0.003668, the test acc is 0.889528
# the epoch 137, the train loss is 0.003044, the test loss is 0.003536, the test acc is 0.889330
# the epoch 138, the train loss is 0.003041, the test loss is 0.003479, the test acc is 0.899445
# the epoch 139, the train loss is 0.002983, the test loss is 0.003396, the test acc is 0.891511
# the epoch 140, the train loss is 0.002980, the test loss is 0.005342, the test acc is 0.859580
# the epoch 141, the train loss is 0.003016, the test loss is 0.004069, the test acc is 0.886355
# the epoch 142, the train loss is 0.003008, the test loss is 0.005005, the test acc is 0.857398
# the epoch 143, the train loss is 0.002925, the test loss is 0.003509, the test acc is 0.892305
# the epoch 144, the train loss is 0.002981, the test loss is 0.005549, the test acc is 0.858985
# the epoch 145, the train loss is 0.002949, the test loss is 0.004012, the test acc is 0.880008
# the epoch 146, the train loss is 0.003024, the test loss is 0.004044, the test acc is 0.883181
# the epoch 147, the train loss is 0.002993, the test loss is 0.003613, the test acc is 0.889131
# the epoch 148, the train loss is 0.002947, the test loss is 0.003959, the test acc is 0.879413
# the epoch 149, the train loss is 0.002934, the test loss is 0.003523, the test acc is 0.891313
# the epoch 150, the train loss is 0.002918, the test loss is 0.003660, the test acc is 0.887941
# the epoch 151, the train loss is 0.002880, the test loss is 0.004256, the test acc is 0.885561
# the epoch 152, the train loss is 0.002842, the test loss is 0.003716, the test acc is 0.887743
# the epoch 153, the train loss is 0.002882, the test loss is 0.003881, the test acc is 0.891115
# the epoch 154, the train loss is 0.002935, the test loss is 0.004431, the test acc is 0.873661
# the epoch 155, the train loss is 0.002828, the test loss is 0.003553, the test acc is 0.897660
# the epoch 156, the train loss is 0.002840, the test loss is 0.004340, the test acc is 0.875645
# the epoch 157, the train loss is 0.002739, the test loss is 0.003673, the test acc is 0.889925
# the epoch 158, the train loss is 0.002871, the test loss is 0.004077, the test acc is 0.888338
# the epoch 159, the train loss is 0.002822, the test loss is 0.003963, the test acc is 0.881991
# early stop
# Done Training!
